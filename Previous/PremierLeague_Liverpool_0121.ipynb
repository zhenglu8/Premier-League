# %%
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"results.csv", encoding = "ISO-8859-1")

# %% [markdown]
# # Home Match

# %%
filt_0102 = df['Season'] == '2001-02'
df[filt_0102]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_0102 = df[filt_0102][filt2]

filt_0203 = df['Season'] == '2002-03'
df[filt_0203]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_0203 = df[filt_0203][filt2]

filt_0304 = df['Season'] == '2003-04'
df[filt_0304]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_0304 = df[filt_0304][filt2]

filt_0405 = df['Season'] == '2004-05'
df[filt_0405]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_0405 = df[filt_0405][filt2]

filt_0506 = df['Season'] == '2005-06'
df[filt_0506]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_0506 = df[filt_0506][filt2]

filt_0607 = df['Season'] == '2006-07'
df[filt_0607]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_0607 = df[filt_0607][filt2]

filt_0708 = df['Season'] == '2007-08'
df[filt_0708]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_0708 = df[filt_0708][filt2]

filt_0809 = df['Season'] == '2008-09'
df[filt_0809]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_0809 = df[filt_0809][filt2]

filt_0910 = df['Season'] == '2009-10'
df[filt_0910]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_0910 = df[filt_0910][filt2]

filt_1011 = df['Season'] == '2010-11'
df[filt_1011]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_1011 = df[filt_1011][filt2]

# %%
filt_1112 = df['Season'] == '2011-12'
df[filt_1112]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_1112 = df[filt_1112][filt2]
HomeMatch_1112
# Out:
#        Season              DateTime   HomeTeam     AwayTeam  FTHG  FTAG FTR  \
# 7006  2011-12  2011-08-13T00:00:00Z  Liverpool   Sunderland     1     1   D
# 7026  2011-12  2011-08-27T00:00:00Z  Liverpool       Bolton     3     1   H
# 7055  2011-12  2011-09-24T00:00:00Z  Liverpool       Wolves     2     1   H
# 7074  2011-12  2011-10-15T00:00:00Z  Liverpool   Man United     1     1   D
# 7085  2011-12  2011-10-22T00:00:00Z  Liverpool      Norwich     1     1   D
# 7106  2011-12  2011-11-05T00:00:00Z  Liverpool      Swansea     0     0   D
# 7131  2011-12  2011-11-27T00:00:00Z  Liverpool     Man City     1     1   D
# 7145  2011-12  2011-12-10T00:00:00Z  Liverpool          QPR     1     0   H
# 7175  2011-12  2011-12-26T00:00:00Z  Liverpool    Blackburn     1     1   D
# 7183  2011-12  2011-12-30T00:00:00Z  Liverpool    Newcastle     3     1   H
# 7207  2011-12  2012-01-14T00:00:00Z  Liverpool        Stoke     0     0   D
# ...

# %%
filt_1213 = df['Season'] == '2012-13'
df[filt_1213]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_1213 = df[filt_1213][filt2]
HomeMatch_1213
# Out:
#        Season              DateTime   HomeTeam     AwayTeam  FTHG  FTAG FTR  \
# 7402  2012-13  2012-08-26T00:00:00Z  Liverpool     Man City     2     2   D
# 7410  2012-13  2012-09-02T00:00:00Z  Liverpool      Arsenal     0     2   A
# 7429  2012-13  2012-09-23T00:00:00Z  Liverpool   Man United     1     2   A
# 7449  2012-13  2012-10-07T00:00:00Z  Liverpool        Stoke     0     0   D
# 7454  2012-13  2012-10-20T00:00:00Z  Liverpool      Reading     1     0   H
# 7480  2012-13  2012-11-04T00:00:00Z  Liverpool    Newcastle     1     1   D
# 7494  2012-13  2012-11-17T00:00:00Z  Liverpool        Wigan     3     0   H
# 7525  2012-13  2012-12-01T00:00:00Z  Liverpool  Southampton     1     0   H
# 7544  2012-13  2012-12-15T00:00:00Z  Liverpool  Aston Villa     1     3   A
# 7553  2012-13  2012-12-22T00:00:00Z  Liverpool       Fulham     4     0   H
# 7590  2012-13  2013-01-02T00:00:00Z  Liverpool   Sunderland     3     0   H
# ...

# %%
filt_1314 = df['Season'] == '2013-14'
df[filt_1314]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_1314 = df[filt_1314][filt2]
HomeMatch_1314
# Out:
#        Season              DateTime   HomeTeam        AwayTeam  FTHG  FTAG  \
# 7765  2013-14  2013-08-17T00:00:00Z  Liverpool           Stoke     1     0
# 7792  2013-14  2013-09-01T00:00:00Z  Liverpool      Man United     1     0
# 7805  2013-14  2013-09-21T00:00:00Z  Liverpool     Southampton     0     1
# 7827  2013-14  2013-10-05T00:00:00Z  Liverpool  Crystal Palace     3     1
# 7846  2013-14  2013-10-26T00:00:00Z  Liverpool       West Brom     4     1
# 7867  2013-14  2013-11-09T00:00:00Z  Liverpool          Fulham     4     0
# 7897  2013-14  2013-12-04T00:00:00Z  Liverpool         Norwich     5     1
# 7905  2013-14  2013-12-07T00:00:00Z  Liverpool        West Ham     4     1
# 7926  2013-14  2013-12-21T00:00:00Z  Liverpool         Cardiff     3     1
# 7957  2013-14  2014-01-01T00:00:00Z  Liverpool            Hull     2     0
# 7976  2013-14  2014-01-18T00:00:00Z  Liverpool     Aston Villa     2     2
# ...

# %%
filt_1415 = df['Season'] == '2014-15'
df[filt_1415]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_1415 = df[filt_1415][filt2]
HomeMatch_1415
# Out:
#        Season              DateTime   HomeTeam        AwayTeam  FTHG  FTAG  \
# 8151  2014-15  2014-08-17T00:00:00Z  Liverpool     Southampton     2     1
# 8177  2014-15  2014-09-13T00:00:00Z  Liverpool     Aston Villa     0     1
# 8198  2014-15  2014-09-27T00:00:00Z  Liverpool         Everton     1     1
# 8207  2014-15  2014-10-04T00:00:00Z  Liverpool       West Brom     2     1
# 8224  2014-15  2014-10-25T00:00:00Z  Liverpool            Hull     0     0
# 8245  2014-15  2014-11-08T00:00:00Z  Liverpool         Chelsea     1     2
# 8265  2014-15  2014-11-29T00:00:00Z  Liverpool           Stoke     1     0
# 8285  2014-15  2014-12-06T00:00:00Z  Liverpool      Sunderland     0     0
# 8311  2014-15  2014-12-21T00:00:00Z  Liverpool         Arsenal     2     2
# 8333  2014-15  2014-12-29T00:00:00Z  Liverpool         Swansea     4     1
# 8336  2014-15  2015-01-01T00:00:00Z  Liverpool       Leicester     2     2
# ...

# %%
filt_1516 = df['Season'] == '2015-16'
df[filt_1516]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_1516 = df[filt_1516][filt2]
HomeMatch_1516
# Out:
#        Season              DateTime   HomeTeam        AwayTeam  FTHG  FTAG  \
# 8543  2015-16  2015-08-17T00:00:00Z  Liverpool     Bournemouth     1     0
# 8557  2015-16  2015-08-29T00:00:00Z  Liverpool        West Ham     0     3
# 8581  2015-16  2015-09-20T00:00:00Z  Liverpool         Norwich     1     1
# 8585  2015-16  2015-09-26T00:00:00Z  Liverpool     Aston Villa     3     2
# 8621  2015-16  2015-10-25T00:00:00Z  Liverpool     Southampton     1     1
# 8643  2015-16  2015-11-08T00:00:00Z  Liverpool  Crystal Palace     1     2
# 8660  2015-16  2015-11-29T00:00:00Z  Liverpool         Swansea     1     0
# 8681  2015-16  2015-12-13T00:00:00Z  Liverpool       West Brom     2     2
# 8697  2015-16  2015-12-26T00:00:00Z  Liverpool       Leicester     1     0
# 8728  2015-16  2016-01-13T00:00:00Z  Liverpool         Arsenal     3     3
# 8741  2015-16  2016-01-17T00:00:00Z  Liverpool      Man United     0     1
# ...

# %%
filt_1617 = df['Season'] == '2016-17'
df[filt_1617]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_

filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_1920 = df[filt_1920][filt2]
HomeMatch_1920
# Out:
#         Season              DateTime   HomeTeam          AwayTeam  FTHG  FTAG  \
# 10044  2019-20  2019-08-09T20:00:00Z  Liverpool           Norwich     4     1
# 10070  2019-20  2019-08-24T17:30:00Z  Liverpool           Arsenal     3     1
# 10084  2019-20  2019-09-14T12:30:00Z  Liverpool         Newcastle     3     1
# 10116  2019-20  2019-10-05T15:00:00Z  Liverpool         Leicester     2     1
# 10142  2019-20  2019-10-27T16:30:00Z  Liverpool         Tottenham     2     1
# 10163  2019-20  2019-11-10T16:30:00Z  Liverpool          Man City     3     1
# 10177  2019-20  2019-11-30T15:00:00Z  Liverpool          Brighton     2     1
# 10191  2019-20  2019-12-04T20:15:00Z  Liverpool           Everton     5     2
# 10204  2019-20  2019-12-14T12:30:00Z  Liverpool           Watford     2     0
# 10241  2019-20  2019-12-29T16:30:00Z  Liverpool            Wolves     1     0
# 10252  2019-20  2020-01-02T20:00:00Z  Liverpool  Sheffield United     2     0
# ...

# %%
filt_2021 = df['Season'] == '2020-21'
df[filt_2021]
filt2 = df['HomeTeam'] == 'Liverpool'
HomeMatch_2021 = df[filt_2021][filt2]
HomeMatch_2021
# Out:
#         Season              DateTime   HomeTeam          AwayTeam  FTHG  FTAG  \
# 10426  2020-21  2020-09-12T17:30:00Z  Liverpool             Leeds     4     3
# 10451  2020-21  2020-09-28T20:00:00Z  Liverpool           Arsenal     3     1
# 10476  2020-21  2020-10-24T20:00:00Z  Liverpool  Sheffield United     2     1
# 10485  2020-21  2020-10-31T17:30:00Z  Liverpool          West Ham     2     1
# 10509  2020-21  2020-11-22T19:15:00Z  Liverpool         Leicester     3     0
# 10529  2020-21  2020-12-06T19:15:00Z  Liverpool            Wolves     4     0
# 10547  2020-21  2020-12-16T20:00:00Z  Liverpool         Tottenham     2     1
# 10569  2020-21  2020-12-27T16:30:00Z  Liverpool         West Brom     1     1
# 10600  2020-21  2021-01-17T16:30:00Z  Liverpool        Man United     0     0
# 10607  2020-21  2021-01-21T20:00:00Z  Liverpool           Burnley     0     1
# 10637  2020-21  2021-02-03T20:15:00Z  Liverpool          Brighton     0     1
# ...

# %%
TotalHomeMatch = pd.concat([HomeMatch_0102, HomeMatch_0203, HomeMatch_0304, HomeMatch_0405, HomeMatch_0506, HomeMatch_0607, HomeMatch_0708, HomeMatch_0809, HomeMatch_0910, HomeMatch_1011, HomeMatch_1112, HomeMatch_1213, HomeMatch_1314, HomeMatch_1415, HomeMatch_1516, HomeMatch_1617, HomeMatch_1718, HomeMatch_1819, HomeMatch_1920, HomeMatch_2021])
TotalHomeMatch
# Out:
#         Season              DateTime   HomeTeam        AwayTeam  FTHG  FTAG  \
# 3208   2001-02  2001-08-18T00:00:00Z  Liverpool        West Ham     2     1
# 3234   2001-02  2001-09-08T00:00:00Z  Liverpool     Aston Villa     1     3
# 3256   2001-02  2001-09-22T00:00:00Z  Liverpool       Tottenham     1     0
# 3278   2001-02  2001-10-13T00:00:00Z  Liverpool           Leeds     1     1
# 3316   2001-02  2001-11-04T00:00:00Z  Liverpool      Man United     3     1
# ...        ...                   ...        ...             ...   ...   ...
# 10694  2020-21  2021-03-07T14:00:00Z  Liverpool          Fulham     0     1
# 10726  2020-21  2021-04-10T15:00:00Z  Liverpool     Aston Villa     2     1
# 10745  2020-21  2021-04-24T12:30:00Z  Liverpool       Newcastle     1     1
# 10765  2020-21  2021-05-08T20:15:00Z  Liverpool     Southampton     2     0
# 10799  2020-21  2021-05-23T16:00:00Z  Liverpool  Crystal Palace     2     0
#
# ...

# %% [markdown]
# # Convert H (Home Win) to 0 (W)

# %%
# Win: 0, Draw: 1, Lose: 2
#df['first_set'] = df['first_set'].replace(['Blue'], 'Green')

TotalHomeMatch['FTR'] = TotalHomeMatch['FTR'].replace(['H','D','A'], [0, 1, 2])
TotalHomeMatch
# Out:
#         Season              DateTime   HomeTeam        AwayTeam  FTHG  FTAG  \
# 3208   2001-02  2001-08-18T00:00:00Z  Liverpool        West Ham     2     1
# 3234   2001-02  2001-09-08T00:00:00Z  Liverpool     Aston Villa     1     3
# 3256   2001-02  2001-09-22T00:00:00Z  Liverpool       Tottenham     1     0
# 3278   2001-02  2001-10-13T00:00:00Z  Liverpool           Leeds     1     1
# 3316   2001-02  2001-11-04T00:00:00Z  Liverpool      Man United     3     1
# ...        ...                   ...        ...             ...   ...   ...
# 10694  2020-21  2021-03-07T14:00:00Z  Liverpool          Fulham     0     1
# 10726  2020-21  2021-04-10T15:00:00Z  Liverpool     Aston Villa     2     1
# 10745  2020-21  2021-04-24T12:30:00Z  Liverpool       Newcastle     1     1
# 10765  2020-21  2021-05-08T20:15:00Z  Liverpool     Southampton     2     0
# 10799  2020-21  2021-05-23T16:00:00Z  Liverpool  Crystal Palace     2     0
#
# ...

# %% [markdown]
# # Home difference

# %%
# Home goal difference
TotalHomeMatch['HGD'] = TotalHomeMatch['FTHG'] - TotalHomeMatch['FTAG']
# Home corner difference
TotalHomeMatch['HCD'] = TotalHomeMatch['HC'] - TotalHomeMatch['AC']
# Home shot difference
TotalHomeMatch['HSD'] = TotalHomeMatch['HS'] - TotalHomeMatch['AS']
# Home shot on target difference
TotalHomeMatch['HSTD'] = TotalHomeMatch['HST'] - TotalHomeMatch['AST']
# Home foul difference
TotalHomeMatch['HFD'] = TotalHomeMatch['HF'] - TotalHomeMatch['AF']
TotalHomeMatch
# Out:
#         Season              DateTime   HomeTeam        AwayTeam  FTHG  FTAG  \
# 3208   2001-02  2001-08-18T00:00:00Z  Liverpool        West Ham     2     1
# 3234   2001-02  2001-09-08T00:00:00Z  Liverpool     Aston Villa     1     3
# 3256   2001-02  2001-09-22T00:00:00Z  Liverpool       Tottenham     1     0
# 3278   2001-02  2001-10-13T00:00:00Z  Liverpool           Leeds     1     1
# 3316   2001-02  2001-11-04T00:00:00Z  Liverpool      Man United     3     1
# ...        ...                   ...        ...             ...   ...   ...
# 10694  2020-21  2021-03-07T14:00:00Z  Liverpool          Fulham     0     1
# 10726  2020-21  2021-04-10T15:00:00Z  Liverpool     Aston Villa     2     1
# 10745  2020-21  2021-04-24T12:30:00Z  Liverpool       Newcastle     1     1
# 10765  2020-21  2021-05-08T20:15:00Z  Liverpool     Southampton     2     0
# 10799  2020-21  2021-05-23T16:00:00Z  Liverpool  Crystal Palace     2     0
#
# ...

# %% [markdown]
# # Home goal and home conceded goal

# %%
print(TotalHomeMatch['FTHG'].sum())
print(TotalHomeMatch['FTAG'].sum())
# Out:
# 757
# 296

# %% [markdown]
# # Home win

# %%
filt3 = TotalHomeMatch['FTHG'] > TotalHomeMatch['FTAG']
TotalHomeWin = TotalHomeMatch[filt3]
TotalHomeWin
#print('Liverpool home win: ' + str(len(HomeWin.index)))
# Out:
#         Season              DateTime   HomeTeam        AwayTeam  FTHG  FTAG  \
# 3208   2001-02  2001-08-18T00:00:00Z  Liverpool        West Ham     2     1
# 3256   2001-02  2001-09-22T00:00:00Z  Liverpool       Tottenham     1     0
# 3316   2001-02  2001-11-04T00:00:00Z  Liverpool      Man United     3     1
# 3335   2001-02  2001-11-25T00:00:00Z  Liverpool      Sunderland     1     0
# 3353   2001-02  2001-12-08T00:00:00Z  Liverpool   Middlesbrough     2     0
# ...        ...                   ...        ...             ...   ...   ...
# 10529  2020-21  2020-12-06T19:15:00Z  Liverpool          Wolves     4     0
# 10547  2020-21  2020-12-16T20:00:00Z  Liverpool       Tottenham     2     1
# 10726  2020-21  2021-04-10T15:00:00Z  Liverpool     Aston Villa     2     1
# 10765  2020-21  2021-05-08T20:15:00Z  Liverpool     Southampton     2     0
# 10799  2020-21  2021-05-23T16:00:00Z  Liverpool  Crystal Palace     2     0
#
# ...

# %% [markdown]
# # Home draw

# %%
filt4 = TotalHomeMatch['FTHG'] == TotalHomeMatch['FTAG']
TotalHomeDraw = TotalHomeMatch[filt4]
TotalHomeDraw
#print('Liverpool home draw: ' + str(len(HomeDraw.index)))
# Out:
#         Season              DateTime   HomeTeam     AwayTeam  FTHG  FTAG  FTR  \
# 3278   2001-02  2001-10-13T00:00:00Z  Liverpool        Leeds     1     1    1
# 3359   2001-02  2001-12-12T00:00:00Z  Liverpool       Fulham     0     0    1
# 3405   2001-02  2002-01-01T00:00:00Z  Liverpool       Bolton     1     1    1
# 3424   2001-02  2002-01-19T00:00:00Z  Liverpool  Southampton     1     1    1
# 3467   2001-02  2002-02-23T00:00:00Z  Liverpool      Everton     1     1    1
# ...        ...                   ...        ...          ...   ...   ...  ...
# 9901   2018-19  2019-01-30T00:00:00Z  Liverpool    Leicester     1     1    1
# 10386  2019-20  2020-07-11T15:00:00Z  Liverpool      Burnley     1     1    1
# 10569  2020-21  2020-12-27T16:30:00Z  Liverpool    West Brom     1     1    1
# 10600  2020-21  2021-01-17T16:30:00Z  Liverpool   Man United     0     0    1
# 10745  2020-21  2021-04-24T12:30:00Z  Liverpool    Newcastle     1     1    1
#
# ...

# %% [markdown]
# # Home lose

# %%
filt5 = TotalHomeMatch['FTHG'] < TotalHomeMatch['FTAG']
TotalHomeLose = TotalHomeMatch[filt5]
TotalHomeLose
#print('Liverpool home lose: ' + str(len(HomeLose.index)))
# Out:
#         Season              DateTime   HomeTeam        AwayTeam  FTHG  FTAG  \
# 3234   2001-02  2001-09-08T00:00:00Z  Liverpool     Aston Villa     1     3
# 3381   2001-02  2001-12-23T00:00:00Z  Liverpool         Arsenal     1     2
# 3740   2002-03  2002-12-01T00:00:00Z  Liverpool      Man United     1     2
# 3946   2002-03  2003-05-03T00:00:00Z  Liverpool        Man City     1     2
# 3973   2003-04  2003-08-17T00:00:00Z  Liverpool         Chelsea     1     2
# 4034   2003-04  2003-10-04T00:00:00Z  Liverpool         Arsenal     1     2
# 4081   2003-04  2003-11-09T00:00:00Z  Liverpool      Man United     1     2
# 4116   2003-04  2003-12-13T00:00:00Z  Liverpool     Southampton     1     2
# 4284   2003-04  2004-04-12T00:00:00Z  Liverpool        Charlton     0     1
# 4456   2004-05  2004-11-06T00:00:00Z  Liverpool      Birmingham     0     1
# 4548   2004-05  2005-01-01T00:00:00Z  Liverpool         Chelsea     0     1
# ...

# %% [markdown]
# # Home corner

# %%
TotalHomeMatch['HC'].sum()
# Out:
# 2776.0

# %% [markdown]
# # Home shots

# %%
TotalHomeMatch['HS'].sum()
# Out:
# 6511.0

# %% [markdown]
# # Home foul committed

# %%
TotalHomeMatch['HF'].sum()
# Out:
# 3834.0

# %% [markdown]
# # Home yellow card

# %%
TotalHomeMatch['HY'].sum()
# Out:
# 372.0

# %% [markdown]
# # Home red card

# %%
TotalHomeMatch['HR'].sum()
# Out:
# 14.0

# %% [markdown]
# # Away Match

# %%
filt_0102 = df['Season'] == '2001-02'
df[filt_0102]
filt2 = df['AwayTeam'] == 'Liverpool'
AwayMatch_0102 = df[filt_0102][filt2]

filt_0203 = df['Season'] == '2002-03'
df[filt_0203]
filt2 = df['AwayTeam'] == 'Liverpool'
AwayMatch_0203 = df[filt_0203][filt2]

filt_0304 = df['Season'] == '2003-04'
df[filt_0304]
filt2 = df['AwayTeam'] == 'Liverpool'
AwayMatch_0304 = df[filt_0304][filt2]

filt_0405 = df['Season'] == '2004-05'
df[filt_0405]
filt2 = df['AwayTeam'] == 'Liverpool'
AwayMatch_0405 = df[filt_0405][filt2]

filt_0506 = df['Season'] == '2005-06'
df[filt_0506]
filt2 = df['AwayTeam'] == 'Liverpool'
AwayMatch_0506 = df[filt_0506][filt2]

filt_0607 = df['Season'] == '2006-07'
df[filt_1112]
filt2 = df['AwayTeam'] == 'Liverpool'
AwayMatch_0607 = df[filt_0607][filt2]

filt_0708 = df['Season'] == '2007-08'
df[filt_0708]
filt2 = df['AwayTeam'] == 'Liverpool'
AwayMatch_0708 = df[filt_0708][filt2]

filt_0809 = df['Season'] == '2008-09'
df[filt_0809]
filt2 = df['AwayTeam'] == 'Liverpool'
AwayMatch_0809 = df[filt_0809][filt2]

filt_0910 = df['Season'] == '2009-10'
df[filt_0910]
filt2 = df['AwayTeam'] == 'Liverpool'
AwayMatch_0910 = df[filt_0910][filt2]

filt_1011 = df['Season'] == '2010-11'
df[filt_1011]
filt2 = df['AwayTeam'] == 'Liverpool'
AwayMatch_1011 = df[filt_1011][filt2]

# %%
filt_1112 = df['Season'] == '2011-12'
df[filt_1112]
filt2 = df['AwayTeam'] == 'Liverpool'
AwayMatch_1112 = df[filt_1112][filt2]
AwayMatch_1112
# Out:
#        Season              DateTime     HomeTeam   AwayTeam  FTHG  FTAG FTR  \
# 7013  2011-12  2011-08-20T00:00:00Z      Arsenal  Liverpool     0     2   A
# 7037  2011-12  2011-09-10T00:00:00Z        Stoke  Liverpool     1     0   H
# 7052  2011-12  2011-09-18T00:00:00Z    Tottenham  Liverpool     4     0   H
# 7065  2011-12  2011-10-01T00:00:00Z      Everton  Liverpool     0     2   A
# 7099  2011-12  2011-10-29T00:00:00Z    West Brom  Liverpool     0     2   A
# 7121  2011-12  2011-11-20T00:00:00Z      Chelsea  Liverpool     1     2   A
# 7142  2011-12  2011-12-05T00:00:00Z       Fulham  Liverpool     1     0   H
# 7159  2011-12  2011-12-18T00:00:00Z  Aston Villa  Liverpool     0     2   A
# 7171  2011-12  2011-12-21T00:00:00Z        Wigan  Liverpool     0     0   D
# 7198  2011-12  2012-01-03T00:00:00Z     Man City  Liverpool     3     0   H
# 7214  2011-12  2012-01-21T00:00:00Z       Bolton  Liverpool     3     1   H
# ...

# %%
filt_1213 = df['Season'] == '2012-13'
df[filt_1213]
filt2 = df['AwayTeam'] == 'Liverpool'
AwayMatch_
# 10775  2020-21  2021-05-13T20:15:00Z  Man United  Liverpool     2     4    0
# 10782  2020-21  2021-05-16T16:30:00Z   West Brom  Liverpool     1     2    0
# 10792  2020-21  2021-05-19T20:15:00Z     Burnley  Liverpool     0     3    0
#
# ...

# %%
# Away goal difference
TotalAwayMatch['AGD'] = TotalAwayMatch['FTAG'] - TotalAwayMatch['FTHG']
# Away corner difference
TotalAwayMatch['ACD'] = TotalAwayMatch['AC'] - TotalAwayMatch['HC']
# Away shot difference
TotalAwayMatch['ASD'] = TotalAwayMatch['AS'] - TotalAwayMatch['HS']
# Away shot on target difference
TotalAwayMatch['ASTD'] = TotalAwayMatch['AST'] - TotalAwayMatch['HST']
# Away foul difference
TotalAwayMatch['AFD'] = TotalAwayMatch['AF'] - TotalAwayMatch['HF']
TotalAwayMatch
# Out:
#         Season              DateTime    HomeTeam   AwayTeam  FTHG  FTAG  FTR  \
# 3229   2001-02  2001-08-27T00:00:00Z      Bolton  Liverpool     2     1    2
# 3242   2001-02  2001-09-15T00:00:00Z     Everton  Liverpool     1     3    0
# 3273   2001-02  2001-09-30T00:00:00Z   Newcastle  Liverpool     0     2    0
# 3287   2001-02  2001-10-20T00:00:00Z   Leicester  Liverpool     1     4    0
# 3298   2001-02  2001-10-27T00:00:00Z    Charlton  Liverpool     0     2    0
# ...        ...                   ...         ...        ...   ...   ...  ...
# 10717  2020-21  2021-04-03T20:00:00Z     Arsenal  Liverpool     0     3    0
# 10739  2020-21  2021-04-19T20:00:00Z       Leeds  Liverpool     1     1    1
# 10775  2020-21  2021-05-13T20:15:00Z  Man United  Liverpool     2     4    0
# 10782  2020-21  2021-05-16T16:30:00Z   West Brom  Liverpool     1     2    0
# 10792  2020-21  2021-05-19T20:15:00Z     Burnley  Liverpool     0     3    0
#
# ...

# %% [markdown]
# # Away goal and away conceded goal

# %%
print(TotalAwayMatch['FTAG'].sum())
print(TotalAwayMatch['FTHG'].sum())
# Out:
# 594
# 447

# %% [markdown]
# # Away win

# %%
filt3 = TotalAwayMatch['FTHG'] < TotalAwayMatch['FTAG']
TotalAwayWin = TotalAwayMatch[filt3]
TotalAwayWin
#print('Liverpool away win: ' + str(len(AwayWin.index)))
# Out:
#         Season              DateTime    HomeTeam   AwayTeam  FTHG  FTAG  FTR  \
# 3242   2001-02  2001-09-15T00:00:00Z     Everton  Liverpool     1     3    0
# 3273   2001-02  2001-09-30T00:00:00Z   Newcastle  Liverpool     0     2    0
# 3287   2001-02  2001-10-20T00:00:00Z   Leicester  Liverpool     1     4    0
# 3298   2001-02  2001-10-27T00:00:00Z    Charlton  Liverpool     0     2    0
# 3340   2001-02  2001-12-01T00:00:00Z       Derby  Liverpool     0     1    0
# ...        ...                   ...         ...        ...   ...   ...  ...
# 10709  2020-21  2021-03-15T20:00:00Z      Wolves  Liverpool     0     1    0
# 10717  2020-21  2021-04-03T20:00:00Z     Arsenal  Liverpool     0     3    0
# 10775  2020-21  2021-05-13T20:15:00Z  Man United  Liverpool     2     4    0
# 10782  2020-21  2021-05-16T16:30:00Z   West Brom  Liverpool     1     2    0
# 10792  2020-21  2021-05-19T20:15:00Z     Burnley  Liverpool     0     3    0
#
# ...

# %% [markdown]
# # Away draw

# %%
filt4 = TotalAwayMatch['FTHG'] == TotalAwayMatch['FTAG']
TotalAwayDraw = TotalAwayMatch[filt4]
TotalAwayDraw
#print('Liverpool away draw: ' + str(len(AwayDraw.index)))
# Out:
#         Season              DateTime   HomeTeam   AwayTeam  FTHG  FTAG  FTR  \
# 3318   2001-02  2001-11-17T00:00:00Z  Blackburn  Liverpool     1     1    1
# 3400   2001-02  2001-12-29T00:00:00Z   West Ham  Liverpool     1     1    1
# 3420   2001-02  2002-01-13T00:00:00Z    Arsenal  Liverpool     1     1    1
# 3607   2002-03  2002-08-28T00:00:00Z  Blackburn  Liverpool     2     2    1
# 3791   2002-03  2002-12-29T00:00:00Z    Arsenal  Liverpool     1     1    1
# ...        ...                   ...        ...        ...   ...   ...  ...
# 10500  2020-21  2020-11-08T16:30:00Z   Man City  Liverpool     1     1    1
# 10513  2020-21  2020-11-28T12:30:00Z   Brighton  Liverpool     1     1    1
# 10538  2020-21  2020-12-13T16:30:00Z     Fulham  Liverpool     1     1    1
# 10578  2020-21  2020-12-30T20:00:00Z  Newcastle  Liverpool     0     0    1
# 10739  2020-21  2021-04-19T20:00:00Z      Leeds  Liverpool     1     1    1
#
# ...

# %% [markdown]
# # Away lose

# %%
filt5 = TotalAwayMatch['FTHG'] > TotalAwayMatch['FTAG']
TotalAwayLose = TotalAwayMatch[filt5]
TotalAwayLose
#print('Liverpool away lose: ' + str(len(AwayLose.index)))
# Out:
#         Season              DateTime       HomeTeam   AwayTeam  FTHG  FTAG  \
# 3229   2001-02  2001-08-27T00:00:00Z         Bolton  Liverpool     2     1
# 3368   2001-02  2001-12-16T00:00:00Z        Chelsea  Liverpool     4     0
# 3411   2001-02  2002-01-09T00:00:00Z    Southampton  Liverpool     2     0
# 3569   2001-02  2002-04-27T00:00:00Z      Tottenham  Liverpool     1     0
# 3709   2002-03  2002-11-09T00:00:00Z  Middlesbrough  Liverpool     1     0
# ...        ...                   ...            ...        ...   ...   ...
# 10363  2019-20  2020-07-02T20:15:00Z       Man City  Liverpool     4     0
# 10398  2019-20  2020-07-15T20:15:00Z        Arsenal  Liverpool     2     1
# 10461  2020-21  2020-10-04T19:15:00Z    Aston Villa  Liverpool     7     2
# 10587  2020-21  2021-01-04T20:00:00Z    Southampton  Liverpool     1     0
# 10649  2020-21  2021-02-13T12:30:00Z      Leicester  Liverpool     3     1
#
# ...

# %% [markdown]
# # Away corner

# %%
TotalAwayMatch['AC'].sum()
# Out:
# 2148.0

# %% [markdown]
# # Away shots

# %%
TotalAwayMatch['AS'].sum()
# Out:
# 5033.0

# %% [markdown]
# # Away foul committed

# %%
TotalAwayMatch['AF'].sum()
# Out:
# 4243.0

# %% [markdown]
# # Away yellow card

# %%
TotalAwayMatch['AY'].sum()
# Out:
# 616.0

# %% [markdown]
# # Away red card

# %%
TotalAwayMatch['AR'].sum()
# Out:
# 26.0

# %% [markdown]
# # Total match

# %%
TotalMatch = pd.concat([TotalHomeMatch, TotalAwayMatch])
TotalMatch = TotalMatch.fillna(0)

TotalMatch['GD'] = TotalMatch['HGD'] + TotalMatch['AGD']
TotalMatch['CD'] = TotalMatch['HCD'] + TotalMatch['ACD']
TotalMatch['SD'] = TotalMatch['HSD'] + TotalMatch['ASD']
TotalMatch['STD'] = TotalMatch['HSTD'] + TotalMatch['ASTD']
TotalMatch['FD'] = TotalMatch['HFD'] + TotalMatch['AFD']

TotalMatch
# Out:
#         Season              DateTime    HomeTeam     AwayTeam  FTHG  FTAG  \
# 3208   2001-02  2001-08-18T00:00:00Z   Liverpool     West Ham     2     1
# 3234   2001-02  2001-09-08T00:00:00Z   Liverpool  Aston Villa     1     3
# 3256   2001-02  2001-09-22T00:00:00Z   Liverpool    Tottenham     1     0
# 3278   2001-02  2001-10-13T00:00:00Z   Liverpool        Leeds     1     1
# 3316   2001-02  2001-11-04T00:00:00Z   Liverpool   Man United     3     1
# ...        ...                   ...         ...          ...   ...   ...
# 10717  2020-21  2021-04-03T20:00:00Z     Arsenal    Liverpool     0     3
# 10739  2020-21  2021-04-19T20:00:00Z       Leeds    Liverpool     1     1
# 10775  2020-21  2021-05-13T20:15:00Z  Man United    Liverpool     2     4
# 10782  2020-21  2021-05-16T16:30:00Z   West Brom    Liverpool     1     2
# 10792  2020-21  2021-05-19T20:15:00Z     Burnley    Liverpool     0     3
#
#        FTR  HTHG  HTAG HTR  ...  AGD  ACD   ASD  ASTD  AFD   GD   CD    SD  \
# ...

# %% [markdown]
# # Total win

# %%
TotalWin = pd.concat([TotalHomeWin, TotalAwayWin])
TotalWin
# Out:
#         Season              DateTime    HomeTeam       AwayTeam  FTHG  FTAG  \
# 3208   2001-02  2001-08-18T00:00:00Z   Liverpool       West Ham     2     1
# 3256   2001-02  2001-09-22T00:00:00Z   Liverpool      Tottenham     1     0
# 3316   2001-02  2001-11-04T00:00:00Z   Liverpool     Man United     3     1
# 3335   2001-02  2001-11-25T00:00:00Z   Liverpool     Sunderland     1     0
# 3353   2001-02  2001-12-08T00:00:00Z   Liverpool  Middlesbrough     2     0
# ...        ...                   ...         ...            ...   ...   ...
# 10709  2020-21  2021-03-15T20:00:00Z      Wolves      Liverpool     0     1
# 10717  2020-21  2021-04-03T20:00:00Z     Arsenal      Liverpool     0     3
# 10775  2020-21  2021-05-13T20:15:00Z  Man United      Liverpool     2     4
# 10782  2020-21  2021-05-16T16:30:00Z   West Brom      Liverpool     1     2
# 10792  2020-21  2021-05-19T20:15:00Z     Burnley      Liverpool     0     3
#
# ...

# %% [markdown]
# # Total draw

# %%
TotalDraw = pd.concat([TotalHomeDraw, TotalAwayDraw])
TotalDraw
# Out:
#         Season              DateTime   HomeTeam     AwayTeam  FTHG  FTAG  FTR  \
# 3278   2001-02  2001-10-13T00:00:00Z  Liverpool        Leeds     1     1    1
# 3359   2001-02  2001-12-12T00:00:00Z  Liverpool       Fulham     0     0    1
# 3405   2001-02  2002-01-01T00:00:00Z  Liverpool       Bolton     1     1    1
# 3424   2001-02  2002-01-19T00:00:00Z  Liverpool  Southampton     1     1    1
# 3467   2001-02  2002-02-23T00:00:00Z  Liverpool      Everton     1     1    1
# ...        ...                   ...        ...          ...   ...   ...  ...
# 10500  2020-21  2020-11-08T16:30:00Z   Man City    Liverpool     1     1    1
# 10513  2020-21  2020-11-28T12:30:00Z   Brighton    Liverpool     1     1    1
# 10538  2020-21  2020-12-13T16:30:00Z     Fulham    Liverpool     1     1    1
# 10578  2020-21  2020-12-30T20:00:00Z  Newcastle    Liverpool     0     0    1
# 10739  2020-21  2021-04-19T20:00:00Z      Leeds    Liverpool     1     1    1
#
# ...

# %% [markdown]
# # Total lose

# %%
TotalLose = pd.concat([TotalHomeLose, TotalAwayLose])
TotalLose
# Out:
#         Season              DateTime     HomeTeam     AwayTeam  FTHG  FTAG  \
# 3234   2001-02  2001-09-08T00:00:00Z    Liverpool  Aston Villa     1     3
# 3381   2001-02  2001-12-23T00:00:00Z    Liverpool      Arsenal     1     2
# 3740   2002-03  2002-12-01T00:00:00Z    Liverpool   Man United     1     2
# 3946   2002-03  2003-05-03T00:00:00Z    Liverpool     Man City     1     2
# 3973   2003-04  2003-08-17T00:00:00Z    Liverpool      Chelsea     1     2
# ...        ...                   ...          ...          ...   ...   ...
# 10363  2019-20  2020-07-02T20:15:00Z     Man City    Liverpool     4     0
# 10398  2019-20  2020-07-15T20:15:00Z      Arsenal    Liverpool     2     1
# 10461  2020-21  2020-10-04T19:15:00Z  Aston Villa    Liverpool     7     2
# 10587  2020-21  2021-01-04T20:00:00Z  Southampton    Liverpool     1     0
# 10649  2020-21  2021-02-13T12:30:00Z    Leicester    Liverpool     3     1
#
# ...

# %% [markdown]
# # Total goal and total conceded goal

# %%
print(TotalHomeMatch['FTHG'].sum() + TotalAwayMatch['FTAG'].sum())
# Out:
# 1351

# %%
print(TotalHomeMatch['FTAG'].sum() + TotalAwayMatch['FTHG'].sum())
# Out:
# 743

# %% [markdown]
# # Total point

# %%
winPoint = len(TotalWin.index) * 3
winPoint

drawPoint = len(TotalDraw.index)
drawPoint

totalPoint = winPoint + drawPoint
totalPoint
# Out:
# 1430

# %% [markdown]
# # Total corner

# %%
print(TotalHomeMatch['HC'].sum() + TotalAwayMatch['AC'].sum())
# Out:
# 4924.0

# %% [markdown]
# # Total shots

# %%
print(TotalHomeMatch['HS'].sum() + TotalAwayMatch['AS'].sum())
# Out:
# 11544.0

# %% [markdown]
# # Total foul committed

# %%
print(TotalHomeMatch['HF'].sum() + TotalAwayMatch['AF'].sum())
# Out:
# 8077.0

# %% [markdown]
# # Total yellow card

# %%
print(TotalHomeMatch['HY'].sum() + TotalAwayMatch['AY'].sum())
# Out:
# 988.0

# %% [markdown]
# # Total red card

# %%
print(TotalHomeMatch['HR'].sum() + TotalAwayMatch['AR'].sum())
# Out:
# 40.0

# %% [markdown]
# # Data visualization

# %%
home_result = []
home_labels = []

home_result.append(len(TotalHomeWin.index))
home_result.append(len(TotalHomeDraw.index))
home_result.append(len(TotalHomeLose.index))
print(home_result)

home_labels.append("Home Win")
home_labels.append("Home Draw")
home_labels.append("Home Lose")
print(home_labels)
# Out:
# [239, 95, 46]
# ['Home Win', 'Home Draw', 'Home Lose']

# %%
plt.style.use("fivethirtyeight")
plt.pie(home_result, labels=home_labels, autopct='%1.1f%%')

plt.title("Liverpool Home Result")
plt.tight_layout()

# %%
away_result = []
away_labels = []

away_result.append(len(TotalAwayWin.index))
away_result.append(len(TotalAwayDraw.index))
away_result.append(len(TotalAwayLose.index))
print(away_result)

away_labels.append("Away Win")
away_labels.append("Away Draw")
away_labels.append("Away Lose")
print(away_labels)
# Out:
# [177, 87, 116]
# ['Away Win', 'Away Draw', 'Away Lose']

# %%
plt.style.use("fivethirtyeight")
plt.pie(away_result, labels=away_labels, autopct='%1.1f%%')

plt.title("Liverpool Away Result")
plt.tight_layout()

# %%
TotalMatch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 760 entries, 3208 to 10792
# Data columns (total 38 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Season    760 non-null    object
#  1   DateTime  760 non-null    object
#  2   HomeTeam  760 non-null    object
#  3   AwayTeam  760 non-null    object
#  4   FTHG      760 non-null    int64
#  5   FTAG      760 non-null    int64
#  6   FTR       760 non-null    int64
#  7   HTHG      760 non-null    float64
#  8   HTAG      760 non-null    float64
#  9   HTR       760 non-null    object
#  10  Referee   760 non-null    object
#  11  HS        760 non-null    float64
#  12  AS        760 non-null    float64
#  13  HST       760 non-null    float64
#  14  AST       760 non-null    float64
#  15  HC        760 non-null    float64
#  16  AC        760 non-null    float64
#  17  HF        760 non-null    float64
#  18  AF        760 non-null    float64
# ...

# %% [markdown]
# FTHG - Full time home goal \
# FTAG  - Full time away goal \
# HS - Home shot \
# AS - Away shot \
# HST - Home shot on target \
# AST - Away shot on target \
# HC - Home corner \
# AC - Away corner \
# HF - Home fouls \
# AF - Away fouls \
# HY - Home yellow card \
# AY - Away yellow card \
# HR - Home red card \
# AR - Away red card

# %% [markdown]
# Features: \
# goals_per_match_diff \
# corners_per_match_diff \
# shots_per_match_diff \
# shotsOnTarget_per_match_diff \
# fouls_per_match_diff

# %%
features = TotalMatch[['CD', 'SD', 'STD', 'FD']]

# %% [markdown]
# Target

# %%
target = TotalMatch['FTR']
target
# Out:
# 3208     0
# 3234     2
# 3256     0
# 3278     1
# 3316     0
#         ..
# 10717    0
# 10739    1
# 10775    0
# 10782    0
# 10792    0
# Name: FTR, Length: 760, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support as score, confusion_matrix, roc_auc_score, classification_report, log_loss

from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression

# %%
X_train,X_test,y_train,y_test = train_test_split(features, target, test_size=0.3, stratify = target)

# %%
names = ["Nearest Neighbors", "Logistic Regression","Linear SVM", "RBF SVM", "Gaussian Process",
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
         "Naive Bayes", "QDA"]

classifiers = [
    KNeighborsClassifier(3),
    LogisticRegression(),
    SVC(kernel="linear", C=0.025, probability=True),
    SVC(gamma=2, C=1, probability=True),
    GaussianProcessClassifier(1.0 * RBF(1.0)),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
    MLPClassifier(alpha=1, max_iter=1000),
    AdaBoostClassifier(),
    GaussianNB(),
    QuadraticDiscriminantAnalysis()]

# %%
for name, clf in zip(names, classifiers):
        clf.fit(X_train, y_train)
        accuracy = clf.score(X_test, y_test)

        # prediction_proba = clf.predict_proba(X_test)
        # logloss = log_loss(y_test,prediction_proba)
        # precision, recall, fscore, support = score(y_test, prediction)
        # conf_martrix = confusion_matrix(y_test, prediction)
        # clas_report = classification_report(y_test, prediction)

        print(name, accuracy)
# Out:
# Nearest Neighbors 0.543859649122807
# Logistic Regression 0.5877192982456141
# Linear SVM 0.6140350877192983
# RBF SVM 0.543859649122807
# Gaussian Process 0.5394736842105263
# Decision Tree 0.5043859649122807
# Random Forest 0.5482456140350878
# Neural Net 0.5526315789473685
# AdaBoost 0.5175438596491229
# Naive Bayes 0.5789473684210527
# QDA 0.5833333333333334
