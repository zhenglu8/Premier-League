# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"results.csv", encoding = "ISO-8859-1")

# %%
filt = df['Season'] == '2020-21'
df[filt]
# Out:
#         Season              DateTime          HomeTeam        AwayTeam  FTHG  \
# 10424  2020-21  2020-09-12T12:30:00Z            Fulham         Arsenal     0
# 10425  2020-21  2020-09-12T15:00:00Z    Crystal Palace     Southampton     1
# 10426  2020-21  2020-09-12T17:30:00Z         Liverpool           Leeds     4
# 10427  2020-21  2020-09-12T20:00:00Z          West Ham       Newcastle     0
# 10428  2020-21  2020-09-13T14:00:00Z         West Brom       Leicester     0
# ...        ...                   ...               ...             ...   ...
# 10799  2020-21  2021-05-23T16:00:00Z         Liverpool  Crystal Palace     2
# 10800  2020-21  2021-05-23T16:00:00Z          Man City         Everton     5
# 10801  2020-21  2021-05-23T16:00:00Z  Sheffield United         Burnley     1
# 10802  2020-21  2021-05-23T16:00:00Z          West Ham     Southampton     3
# 10803  2020-21  2021-05-23T16:00:00Z            Wolves      Man United     1
#
# ...

# %%
df[filt].to_csv("20-21_DB_Test.csv", encoding='ISO-8859-1')
