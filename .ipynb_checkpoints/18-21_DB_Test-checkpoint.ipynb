# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"results.csv", encoding = "ISO-8859-1")

# %%
filt = (df['Season'] == '2018-19') | (df['Season'] == '2019-20') | (df['Season'] == '2020-21')
df[filt]
# Out:
#         Season              DateTime          HomeTeam        AwayTeam  FTHG  \
# 9664   2018-19  2018-08-10T00:00:00Z        Man United       Leicester     2
# 9665   2018-19  2018-08-11T00:00:00Z       Bournemouth         Cardiff     2
# 9666   2018-19  2018-08-11T00:00:00Z            Fulham  Crystal Palace     0
# 9667   2018-19  2018-08-11T00:00:00Z      Huddersfield         Chelsea     0
# 9668   2018-19  2018-08-11T00:00:00Z         Newcastle       Tottenham     1
# ...        ...                   ...               ...             ...   ...
# 10799  2020-21  2021-05-23T16:00:00Z         Liverpool  Crystal Palace     2
# 10800  2020-21  2021-05-23T16:00:00Z          Man City         Everton     5
# 10801  2020-21  2021-05-23T16:00:00Z  Sheffield United         Burnley     1
# 10802  2020-21  2021-05-23T16:00:00Z          West Ham     Southampton     3
# 10803  2020-21  2021-05-23T16:00:00Z            Wolves      Man United     1
#
# ...

# %%
df[filt].to_csv("18-21_DB_Test.csv", encoding='ISO-8859-1')
