# %%
import pandas as pd
from matplotlib import pyplot

# %%
df = pd.read_csv(r"results.csv", encoding = "ISO-8859-1")

# %%
HomeTeam = 'Liverpool'
AwayTeam = 'Arsenal'

filt = df['HomeTeam'] == HomeTeam
filt2 = df['AwayTeam'] == AwayTeam
filt3 = df['Season'] >= '2007-08'
TotalMatch = df[filt][filt2][filt3]
TotalMatch
# Out:
# /var/folders/fs/7xwm968n3gz7y_pc2ghf916c0000gn/T/ipykernel_13569/1716971122.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   TotalMatch = df[filt][filt2][filt3]
#         Season              DateTime   HomeTeam AwayTeam  FTHG  FTAG FTR  \
# 5589   2007-08  2007-10-28T00:00:00Z  Liverpool  Arsenal     1     1   D
# 6190   2008-09  2009-04-21T00:00:00Z  Liverpool  Arsenal     4     4   D
# 6402   2009-10  2009-12-13T00:00:00Z  Liverpool  Arsenal     1     2   A
# 6632   2010-11  2010-08-15T00:00:00Z  Liverpool  Arsenal     1     1   D
# 7264   2011-12  2012-03-03T00:00:00Z  Liverpool  Arsenal     1     2   A
# 7410   2012-13  2012-09-02T00:00:00Z  Liverpool  Arsenal     0     2   A
# 8007   2013-14  2014-02-08T00:00:00Z  Liverpool  Arsenal     5     1   H
# 8311   2014-15  2014-12-21T00:00:00Z  Liverpool  Arsenal     2     2   D
# 8728   2015-16  2016-01-13T00:00:00Z  Liverpool  Arsenal     3     3   D
# ...

# %%
# Home goal difference
TotalMatch['HGD'] = TotalMatch['FTHG'] - TotalMatch['FTAG']
# Home corner difference
TotalMatch['HCD'] = TotalMatch['HC'] - TotalMatch['AC']
# Home shot difference
TotalMatch['HSD'] = TotalMatch['HS'] - TotalMatch['AS']
# Home shot on target difference
TotalMatch['HSTD'] = TotalMatch['HST'] - TotalMatch['AST']
# Home foul difference
TotalMatch['HFD'] = TotalMatch['HF'] - TotalMatch['AF']
TotalMatch
# Out:
#         Season              DateTime   HomeTeam AwayTeam  FTHG  FTAG FTR  \
# 5589   2007-08  2007-10-28T00:00:00Z  Liverpool  Arsenal     1     1   D
# 6190   2008-09  2009-04-21T00:00:00Z  Liverpool  Arsenal     4     4   D
# 6402   2009-10  2009-12-13T00:00:00Z  Liverpool  Arsenal     1     2   A
# 6632   2010-11  2010-08-15T00:00:00Z  Liverpool  Arsenal     1     1   D
# 7264   2011-12  2012-03-03T00:00:00Z  Liverpool  Arsenal     1     2   A
# 7410   2012-13  2012-09-02T00:00:00Z  Liverpool  Arsenal     0     2   A
# 8007   2013-14  2014-02-08T00:00:00Z  Liverpool  Arsenal     5     1   H
# 8311   2014-15  2014-12-21T00:00:00Z  Liverpool  Arsenal     2     2   D
# 8728   2015-16  2016-01-13T00:00:00Z  Liverpool  Arsenal     3     3   D
# 9163   2016-17  2017-03-04T00:00:00Z  Liverpool  Arsenal     3     1   H
# 9311   2017-18  2017-08-27T00:00:00Z  Liverpool  Arsenal     4     0   H
# 9857   2018-19  2018-12-29T00:00:00Z  Liverpool  Arsenal     5     1   H
# ...

# %%
TotalMatch[['Season','HCD']]
# Out:
#         Season   HCD
# 5589   2007-08   3.0
# 6190   2008-09  12.0
# 6402   2009-10  -1.0
# 6632   2010-11  -2.0
# 7264   2011-12  12.0
# 7410   2012-13   8.0
# 8007   2013-14   0.0
# 8311   2014-15   4.0
# 8728   2015-16   6.0
# 9163   2016-17   6.0
# 9311   2017-18   1.0
# 9857   2018-19   2.0
# 10070  2019-20   2.0
# 10451  2020-21   4.0
# 10921  2021-22   5.0

# %%
list1 = TotalMatch['HCD']
print(list1.values.tolist())
# Out:
# [3.0, 12.0, -1.0, -2.0, 12.0, 8.0, 0.0, 4.0, 6.0, 6.0, 1.0, 2.0, 2.0, 4.0, 5.0]

# %%
TotalMatch[['Season','HCD']].plot(x="Season",y="HCD")
pyplot.show()

# %%
TotalMatch[['Season','HSD']]
# Out:
#         Season   HSD
# 5589   2007-08   0.0
# 6190   2008-09  14.0
# 6402   2009-10  -1.0
# 6632   2010-11  -7.0
# 7264   2011-12   2.0
# 7410   2012-13   6.0
# 8007   2013-14  11.0
# 8311   2014-15  20.0
# 8728   2015-16   8.0
# 9163   2016-17  11.0
# 9311   2017-18  10.0
# 9857   2018-19   7.0
# 10070  2019-20  16.0
# 10451  2020-21  17.0
# 10921  2021-22  14.0

# %%
TotalMatch[['Season','HSD']].plot(x="Season",y="HSD")
pyplot.show()

# %%
TotalMatch[['Season','HSTD']]
# Out:
#         Season  HSTD
# 5589   2007-08   4.0
# 6190   2008-09  11.0
# 6402   2009-10  -2.0
# 6632   2010-11  -3.0
# 7264   2011-12  -3.0
# 7410   2012-13   1.0
# 8007   2013-14   6.0
# 8311   2014-15   7.0
# 8728   2015-16   1.0
# 9163   2016-17   4.0
# 9311   2017-18  10.0
# 9857   2018-19   8.0
# 10070  2019-20   2.0
# 10451  2020-21   5.0
# 10921  2021-22   6.0

# %%
TotalMatch[['Season','HSTD']].plot(x="Season",y="HSTD")
pyplot.show()

# %%
TotalMatch[['Season','HFD']]
# Out:
#         Season  HFD
# 5589   2007-08  6.0
# 6190   2008-09 -2.0
# 6402   2009-10  3.0
# 6632   2010-11 -2.0
# 7264   2011-12  2.0
# 7410   2012-13  5.0
# 8007   2013-14  0.0
# 8311   2014-15 -8.0
# 8728   2015-16  2.0
# 9163   2016-17 -7.0
# 9311   2017-18 -3.0
# 9857   2018-19 -5.0
# 10070  2019-20  3.0
# 10451  2020-21  4.0
# 10921  2021-22  3.0

# %%
TotalMatch[['Season','HFD']].plot(x="Season",y="HFD")
pyplot.show()

# %%
TotalMatch[['Season','HCD','HSD','HSTD','HFD']]
# Out:
#         Season   HCD   HSD  HSTD  HFD
# 5589   2007-08   3.0   0.0   4.0  6.0
# 6190   2008-09  12.0  14.0  11.0 -2.0
# 6402   2009-10  -1.0  -1.0  -2.0  3.0
# 6632   2010-11  -2.0  -7.0  -3.0 -2.0
# 7264   2011-12  12.0   2.0  -3.0  2.0
# 7410   2012-13   8.0   6.0   1.0  5.0
# 8007   2013-14   0.0  11.0   6.0  0.0
# 8311   2014-15   4.0  20.0   7.0 -8.0
# 8728   2015-16   6.0   8.0   1.0  2.0
# 9163   2016-17   6.0  11.0   4.0 -7.0
# 9311   2017-18   1.0  10.0  10.0 -3.0
# 9857   2018-19   2.0   7.0   8.0 -5.0
# 10070  2019-20   2.0  16.0   2.0  3.0
# 10451  2020-21   4.0  17.0   5.0  4.0
# 10921  2021-22   5.0  14.0   6.0  3.0

# %%
TotalMatch[['Season','HCD','HSD','HSTD','HFD']].plot(x="Season",y=['HCD','HSD','HSTD','HFD'])
pyplot.show()
